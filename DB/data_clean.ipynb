# %%
import pandas as pd

df_full = pd.read_csv('data.csv')
df_full.head(2)
# Out:
#    Unnamed: 0  user_id                   location      age        isbn  \
# 0           0        2  stockton, california, usa  18.0000  0195153448
# 1           1        8   timmins, ontario, canada  34.7439  0002005018
#
#    rating           book_title           book_author  year_of_publication  \
# 0       0  Classical Mythology    Mark P. O. Morford               2002.0
# 1       5         Clara Callan  Richard Bruce Wright               2001.0
#
#                  publisher                                              img_s  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                                img_m  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
#
#                                                img_l  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
#
#                                              Summary Language  \
# 0  Provides an introduction to classical myths pl...       en
# 1  In a small town in Canada, Clara Callan reluct...       en
#
#              Category      city       state country
# 0  ['Social Science']  stockton  california     usa
# 1       ['Actresses']   timmins     ontario  canada

# %%
# 1031175 is really heavy to proccess and showcase a demo so we are considering 10 % of it
df_full.shape
# Out:
# (1031175, 19)

# %%
random_seed = 42
df = df_full.sample(n=100000, random_state=random_seed)
df.shape
# Out:
# (100000, 19)

# %% [markdown]
# ### Drop unnecessary columns like img_s, img_m, img_l

# %%
df = df.drop(columns=['img_s', 'img_m', 'img_l', 'Unnamed: 0', 'Summary'])
df.head()
# Out:
#         user_id                                location      age        isbn  \
# 392141   262169              walled lake, michigan, usa  15.0000  0345388216
# 120888    73651                   grapevine, texas, usa  34.7439  0553375407
# 472434   217565  siegburg, nordrhein-westfalen, germany  34.7439  340412815X
# 206129   185233                 winnemucca, nevada, usa  31.0000  0452278902
# 553117    69697        west sacramento, california, usa  24.0000  037327145X
#
#         rating                                         book_title  \
# 392141       0           Dragonseye (Dragonriders of Pern Series)
# 120888       0       Ishmael: An Adventure of the Mind and Spirit
# 472434       0                       Die BrÃ?Â¼cken der Freiheit.
# 206129       5          The Green Mile: The Complete Serial Novel
# 553117       0  Whitelaw'S Wedding (The Protectors) (Silhouett...
#
#            book_author  year_of_publication         publisher Language  \
# 392141  Anne McCaffrey               1997.0  Ballantine Books       en
# 120888    Daniel Quinn               1995.0            Bantam       en
# 472434     Ken Follett               1998.0          LÃ?Â¼bbe       de
# 206129    Stephen King               1997.0       Plume Books        9
# 553117  Beverly Barton               2001.0        Silhouette       en
#
#                         Category             city                state  \
# 392141               ['Fiction']      walled lake             michigan
# 120888               ['Fiction']        grapevine                texas
# 472434  ['Highlands (Scotland)']         siegburg  nordrhein-westfalen
# 206129                         9       winnemucca               nevada
# 553117               ['Fiction']  west sacramento           california
#
#         country
# 392141      usa
# 120888      usa
# 472434  germany
# 206129      usa
# 553117      usa

# %% [markdown]
# ### Check for NaN values in each column

# %%
# for col in df.columns:
df.isnull().sum()
# Out:
# user_id                   0
# location                  0
# age                       0
# isbn                      0
# rating                    0
# book_title                0
# book_author               0
# year_of_publication       0
# publisher                 0
# Language                  0
# Category                  0
# city                   1309
# state                  2193
# country                3445
# dtype: int64

# %%
# Later the RAG app can analyze on missing data too
df.fillna("Unknown", inplace=True)

# %%
df.isnull().sum()
# Out:
# user_id                0
# location               0
# age                    0
# isbn                   0
# rating                 0
# book_title             0
# book_author            0
# year_of_publication    0
# publisher              0
# Language               0
# Category               0
# city                   0
# state                  0
# country                0
# dtype: int64

# %% [markdown]
# ### Fixing data types of age and year_of_publication

# %%
print(df.dtypes)
# Out:
# user_id                  int64
# location                object
# age                    float64
# isbn                    object
# rating                   int64
# book_title              object
# book_author             object
# year_of_publication    float64
# publisher               object
# Language                object
# Category                object
# city                    object
# state                   object
# country                 object
# dtype: object

# %%
convert_dict = {'age': int,
                'year_of_publication': int
                }
 
df = df.astype(convert_dict)
print(df.dtypes)
# Out:
# user_id                 int64
# location               object
# age                     int32
# isbn                   object
# rating                  int64
# book_title             object
# book_author            object
# year_of_publication     int32
# publisher              object
# Language               object
# Category               object
# city                   object
# state                  object
# country                object
# dtype: object

# %%
df.head(3)
# Out:
#         user_id                                location  age        isbn  \
# 392141   262169              walled lake, michigan, usa   15  0345388216
# 120888    73651                   grapevine, texas, usa   34  0553375407
# 472434   217565  siegburg, nordrhein-westfalen, germany   34  340412815X
#
#         rating                                    book_title     book_author  \
# 392141       0      Dragonseye (Dragonriders of Pern Series)  Anne McCaffrey
# 120888       0  Ishmael: An Adventure of the Mind and Spirit    Daniel Quinn
# 472434       0                  Die BrÃ?Â¼cken der Freiheit.     Ken Follett
#
#         year_of_publication         publisher Language  \
# 392141                 1997  Ballantine Books       en
# 120888                 1995            Bantam       en
# 472434                 1998          LÃ?Â¼bbe       de
#
#                         Category         city                state  country
# 392141               ['Fiction']  walled lake             michigan      usa
# 120888               ['Fiction']    grapevine                texas      usa
# 472434  ['Highlands (Scotland)']     siegburg  nordrhein-westfalen  germany

# %%
df['location'].replace('n/a, n/a, n/a', 'Unknown', inplace=True)
df['Language'].replace('9', 'Unknown', inplace=True)
df['Category'].replace('9', 'Unknown', inplace=True)
df['state'].replace(',', 'Unknown', inplace=True)
df.head()
# Out:
# C:\Users\dsilv\AppData\Local\Temp\ipykernel_9896\2990216996.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['location'].replace('n/a, n/a, n/a', 'Unknown', inplace=True)
# C:\Users\dsilv\AppData\Local\Temp\ipykernel_9896\2990216996.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Language'].replace('9', 'Unknown', inplace=True)
# C:\Users\dsilv\AppData\Local\Temp\ipykernel_9896\2990216996.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Category'].replace('9', 'Unknown', inplace=True)
# C:\Users\dsilv\AppData\Local\Temp\ipykernel_9896\2990216996.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['state'].replace(',', 'Unknown', inplace=True)
#         user_id                                location  age        isbn  \
# 392141   262169              walled lake, michigan, usa   15  0345388216
# 120888    73651                   grapevine, texas, usa   34  0553375407
# 472434   217565  siegburg, nordrhein-westfalen, germany   34  340412815X
# 206129   185233                 winnemucca, nevada, usa   31  0452278902
# 553117    69697        west sacramento, california, usa   24  037327145X
#
#         rating                                         book_title  \
# 392141       0           Dragonseye (Dragonriders of Pern Series)
# 120888       0       Ishmael: An Adventure of the Mind and Spirit
# 472434       0                       Die BrÃ?Â¼cken der Freiheit.
# 206129       5          The Green Mile: The Complete Serial Novel
# 553117       0  Whitelaw'S Wedding (The Protectors) (Silhouett...
#
#            book_author  year_of_publication         publisher Language  \
# 392141  Anne McCaffrey                 1997  Ballantine Books       en
# 120888    Daniel Quinn                 1995            Bantam       en
# 472434     Ken Follett                 1998          LÃ?Â¼bbe       de
# 206129    Stephen King                 1997       Plume Books  Unknown
# 553117  Beverly Barton                 2001        Silhouette       en
#
#                         Category             city                state  \
# 392141               ['Fiction']      walled lake             michigan
# 120888               ['Fiction']        grapevine                texas
# 472434  ['Highlands (Scotland)']         siegburg  nordrhein-westfalen
# 206129                   Unknown       winnemucca               nevada
# 553117               ['Fiction']  west sacramento           california
#
#         country
# 392141      usa
# 120888      usa
# 472434  germany
# 206129      usa
# 553117      usa

# %% [markdown]
# ### Save the file to .csv

# %%
df.to_csv('db_data.csv')
